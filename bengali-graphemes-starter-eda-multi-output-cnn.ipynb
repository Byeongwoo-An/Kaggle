# %% [markdown]
# # Reference
#
# https://www.kaggle.com/kaushal2896/bengali-graphemes-starter-eda-multi-output-cnn

# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
from tqdm.auto import tqdm
from glob import glob
import time, gc
import cv2

from tensorflow import keras
import matplotlib.image as mpimg
from keras.preprocessing.image import ImageDataGenerator
from keras.models import Model
from keras.models import clone_model
from keras.layers import Dense,Conv2D,Flatten,MaxPool2D,Dropout,BatchNormalization, Input
from keras.optimizers import Adam
from keras.callbacks import ReduceLROnPlateau
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix
import PIL.Image as Image, PIL.ImageDraw as ImageDraw, PIL.ImageFont as ImageFont
from matplotlib import pyplot as plt
import seaborn as sns

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# Any results you write to the current directory are saved as output.
# Out:
# Using TensorFlow backend.
# /kaggle/input/kalpurush-fonts/kalpurush-2.ttf
# /kaggle/input/bengaliai-cv19/test_image_data_2.parquet
# /kaggle/input/bengaliai-cv19/sample_submission.csv
# /kaggle/input/bengaliai-cv19/class_map.csv
# /kaggle/input/bengaliai-cv19/train_image_data_2.parquet
# /kaggle/input/bengaliai-cv19/train_multi_diacritics.csv
# /kaggle/input/bengaliai-cv19/train_image_data_0.parquet
# /kaggle/input/bengaliai-cv19/train_image_data_3.parquet
# /kaggle/input/bengaliai-cv19/test_image_data_0.parquet
# /kaggle/input/bengaliai-cv19/test_image_data_1.parquet
# /kaggle/input/bengaliai-cv19/train.csv
# /kaggle/input/bengaliai-cv19/test.csv
# /kaggle/input/bengaliai-cv19/train_image_data_1.parquet
# /kaggle/input/bengaliai-cv19/class_map_corrected.csv
# /kaggle/input/bengaliai-cv19/test_image_data_3.parquet

# %%
train_df_ = pd.read_csv('/kaggle/input/bengaliai-cv19/train.csv')
test_df_ = pd.read_csv('/kaggle/input/bengaliai-cv19/test.csv')
class_map_df = pd.read_csv('/kaggle/input/bengaliai-cv19/class_map.csv')
sample_sub_df = pd.read_csv('/kaggle/input/bengaliai-cv19/sample_submission.csv')

# %%
train_df_.head()
# Out:
#   image_id  grapheme_root  vowel_diacritic  consonant_diacritic grapheme
# 0  Train_0             15                9                    5   ক্ট্রো
# 1  Train_1            159                0                    0        হ
# 2  Train_2             22                3                    5     খ্রী
# 3  Train_3             53                2                    2     র্টি
# 4  Train_4             71                9                    5     থ্রো

# %%
test_df_.head()
# Out:
#                        row_id image_id            component
# 0  Test_0_consonant_diacritic   Test_0  consonant_diacritic
# 1        Test_0_grapheme_root   Test_0        grapheme_root
# 2      Test_0_vowel_diacritic   Test_0      vowel_diacritic
# 3  Test_1_consonant_diacritic   Test_1  consonant_diacritic
# 4        Test_1_grapheme_root   Test_1        grapheme_root

# %%
sample_sub_df.head()
# Out:
#                        row_id  target
# 0  Test_0_consonant_diacritic       0
# 1        Test_0_grapheme_root       0
# 2      Test_0_vowel_diacritic       0
# 3  Test_1_consonant_diacritic       0
# 4        Test_1_grapheme_root       0

# %%
class_map_df.head()
# Out:
#   component_type  label component
# 0  grapheme_root      0         ং
# 1  grapheme_root      1         ঃ
# 2  grapheme_root      2         অ
# 3  grapheme_root      3         আ
# 4  grapheme_root      4         ই

# %%
print(f'Size of training data: {train_df_.shape}')
print(f'Size of test data: {test_df_.shape}')
print(f'Size of class map: {class_map_df.shape}')
# Out:
# Size of training data: (200840, 5)
# Size of test data: (36, 3)
# Size of class map: (186, 3)

# %% [markdown]
# # EDA

# %%
HEIGHT = 236
WIDTH = 236

def get_n(df, field, n, top=True):
    top_graphemes = df.groupby([field]).size().reset_index(name='counts')['counts'].sort_values(ascending=not top)[:n]
    top_grapheme_roots = top_graphemes.index
    top_grapheme_counts = top_graphemes.values
    top_graphemes = class_map_df[class_map_df['component_type'] == field].reset_index().iloc[top_grapheme_roots]
    top_graphemes.drop(['component_type', 'label'], axis=1, inplace=True)
    top_graphemes.loc[:, 'count'] = top_grapheme_counts
    return top_graphemes

def image_from_char(char):
    image = Image.new('RGB', (WIDTH, HEIGHT))
    draw = ImageDraw.Draw(image)
    myfont = ImageFont.truetype('/kaggle/input/kalpurush-fonts/kalpurush-2.ttf', 120)
    w, h = draw.textsize(char, font=myfont)
    draw.text(((WIDTH - w) / 2,(HEIGHT - h) / 3), char, font=myfont)

    return image

# %%
print(f'Number of unique grapheme roots: {train_df_["grapheme_root"].nunique()}')
print(f'Number of unique vowel diacritic: {train_df_["vowel_diacritic"].nunique()}')
print(f'Number of unique consonant diacritic: {train_df_["consonant_diacritic"].nunique()}')
# Out:
# Number of unique grapheme roots: 168
# Number of unique vowel diacritic: 11
# Number of unique consonant diacritic: 7

# %%
top_10_roots = get_n(train_df_, 'grapheme_root', 10)
top_10_roots
# Out:
#      index component  count
# 72      72         দ   5736
# 64      64         ত   5596
# 13      13         ক   5420
# 107    107         ব   5321
# 23      23         গ   5149
# 96      96         প   4926
# 113    113         ভ   4395
# 147    147         স   4392
# 133    133         শ   4374
# 115    115         ম   4015

# %%
f, ax = plt.subplots(2, 5, figsize=(16, 8))
ax = ax.flatten()

for i in range(10):
    ax[i].imshow(image_from_char(top_10_roots['component'].iloc[i]), cmap='Greys')

# %%
components = ['consonant_diacritic', 'grapheme_root', 'vowel_diacritic']
target=[] # model predictions placeholder
row_id=[] # row_id place holder
for i in range(4):
    df_test_img = pd.read_parquet('/kaggle/input/bengaliai-cv19/test_image_data_{}.parquet'.format(i)) 
    df_test_img.set_index('image_id', inplace=True)

    X_test = resize(df_test_img, need_progress_bar=False)/255
    X_test = X_test.values.reshape(-1, IMG_SIZE, IMG_SIZE, N_CHANNELS)
    
    preds = model.predict(X_test)

    for i, p in enumerate(preds_dict):
        preds_dict[p] = np.argmax(preds[i], axis=1)

    for k,id in enumerate(df_test_img.index.values):  
        for i,comp in enumerate(components):
            id_sample=id+'_'+comp
            row_id.append(id_sample)
            target.append(preds_dict[comp][k])
    del df_test_img
    del X_test
    gc.collect()

df_sample = pd.DataFrame(
    {
        'row_id': row_id,
        'target':target
    },
    columns = ['row_id','target'] 
)
df_sample.to_csv('submission.csv',index=False)
df_sample.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-12-e002587cb1a4> in <module>
#       6     df_test_img.set_index('image_id', inplace=True)
#       7
# ----> 8     X_test = resize(df_test_img, need_progress_bar=False)/255
#       9     X_test = X_test.values.reshape(-1, IMG_SIZE, IMG_SIZE, N_CHANNELS)
#      10
#
# NameError: name 'resize' is not defined

# %%
f, ax = plt.subplots(2, 5, figsize=(16, 8))
ax = ax.flatten()

for i in range(10):
    ax[i].imshow(image_from_char(top_10_roots['component'].iloc[i]), cmap='Greys')

# %%
bottom_10_roots = get_n(train_df_, 'grapheme_root', 10, False)
bottom_10_roots
# Out:
#      index component  count
# 73      73       দ্ঘ    130
# 33      33     ঙ্ক্ত    136
# 102    102       প্স    141
# 158    158       স্স    143
# 45      45     জ্জ্ব    144
# 130    130       ল্ব    144
# 1        1         ঃ    145
# 12      12         ঔ    146
# 0        0         ং    147
# 63      63       ণ্ণ    149

# %%
f, ax = plt.subplots(2, 5, figsize=(16, 8))
ax = ax.flatten()

for i in range(10):
    ax[i].imshow(image_from_char(bottom_10_roots['component'].iloc[i]), cmap='Greys')

# %%
top_5_vowels = get_n(train_df_, 'vowel_diacritic', 5)
top_5_vowels
# Out:
#    index component  count
# 0    168         0  41508
# 1    169         া  36886
# 7    175         ে  28723
# 2    170         ি  25967
# 4    172         ু  18848

# %%
f, ax = plt.subplots(1, 5, figsize=(16, 8))
ax = ax.flatten()

for i in range(5):
    ax[i].imshow(image_from_char(top_5_vowels['component'].iloc[i]), cmap='Greys')

# %%
top_5_consonants = get_n(train_df_, 'consonant_diacritic', 5)
top_5_consonants
# Out:
#    index component   count
# 0    179         0  125278
# 2    181        র্   23465
# 5    184        ্র   21397
# 4    183        ্য   21270
# 1    180         ঁ    7424

# %%
f, ax = plt.subplots(1, 5, figsize=(16, 8))
ax = ax.flatten()

for i in range(5):
    ax[i].imshow(image_from_char(top_5_consonants['component'].iloc[i]), cmap='Greys')

# %%
train_df_ = train_df_.drop(['grapheme'],axis=1,inplace=False)

# %%
train_df_[['grapheme_root', 'vowel_diacritic', 'consonant_diacritic']] = train_df_[['grapheme_root', 'vowel_diacritic', 'consonant_diacritic']].astype('uint8')

# %%
IMG_SIZE=64
N_CHANNELS=1

# %%
def resize(df, size=64, need_progress_bar=True):
    resized = {}
    resize_size=64
    if need_progress_bar:
        for i in tqdm(range(df.shape[0])):
            image=df.loc[df.index[i]].values.reshape(137,236)
            _, thresh = cv2.threshold(image, 30, 255, cv2.THRESH_BINARY_INV + cv2.THRESH_OTSU)
            contours, _ = cv2.findContours(thresh,cv2.RETR_LIST,cv2.CHAIN_APPROX_SIMPLE)[-2:]

            idx = 0 
            ls_xmin = []
            ls_ymin = []
            ls_xmax = []
            ls_ymax = []
            for cnt in contours:
                idx += 1
                x,y,w,h = cv2.boundingRect(cnt)
                ls_xmin.append(x)
                ls_ymin.append(y)
                ls_xmax.append(x + w)
                ls_ymax.append(y + h)
            xmin = min(ls_xmin)
            ymin = min(ls_ymin)
            xmax = max(ls_xmax)
            ymax = max(ls_ymax)

            roi = image[ymin:ymax,xmin:xmax]
            resized_roi = cv2.resize(roi, (resize_size, resize_size),interpolation=cv2.INTER_AREA)
            resized[df.index[i]] = resized_roi.reshape(-1)
    else:
        for i in range(df.shape[0]):
            #image = cv2.resize(df.loc[df.index[i]].values.reshape(137,236),(size,size),None,fx=0.5,fy=0.5,interpolation=cv2.INTER_AREA)
            image=df.loc[df.index[i]].values.reshape(137,236)
            _, thresh = cv2.threshold(image, 30, 255, cv2.THRESH_BINARY_INV + cv2.THRESH_OTSU)
            contours, _ = cv2.findContours(thresh,cv2.RETR_LIST,cv2.CHAIN_APPROX_SIMPLE)[-2:]

            idx = 0 
            ls_xmin = []
            ls_ymin = []
            ls_xmax = []
            ls_ymax = []
            for cnt in contours:
                idx += 1
                x,y,w,h = cv2.boundingRect(cnt)
                ls_xmin.append(x)
                ls_ymin.append(y)
                ls_xmax.append(x + w)
                ls_ymax.append(y + h)
            xmin = min(ls_xmin)
            ymin = min(ls_ymin)
            xmax = max(ls_xmax)
            ymax = max(ls_ymax)

            roi = image[ymin:ymax,xmin:xmax]
            resized_roi = cv2.resize(roi, (resize_size, resize_size),interpolation=cv2.INTER_AREA)
            resized[df.index[i]] = resized_roi.reshape(-1)
    resized = pd.DataFrame(resized).T
    return resized
def get_dummies(df):
    cols = []
    for col in df:
        cols.append(pd.get_dummies(df[col].astype(str)))
    return pd.concat(cols, axis=1)

# %%
def resize(df, size=64, need_progress_bar=True):
    resized = {}
    resize_size=64
    if need_progress_bar:
        for i in tqdm(range(df.shape[0])):
            image=df.loc[df.index[i]].values.reshape(137,236)
            _, thresh = cv2.threshold(image, 30, 255, cv2.THRESH_BINARY_INV + cv2.THRESH_OTSU)
            contours, _ = cv2.findContours(thresh,cv2.RETR_LIST,cv2.CHAIN_APPROX_SIMPLE)[-2:]

            idx = 0 
            ls_xmin = []
            ls_ymin = []
            ls_xmax = []
            ls_ymax = []
            for cnt in contours:
                idx += 1
                x,y,w,h = cv2.boundingRect(cnt)
                ls_xmin.append(x)
                ls_ymin.append(y)
                ls_xmax.append(x + w)
                ls_ymax.append(y + h)
            xmin = min(ls_xmin)
            ymin = min(ls_ymin)
            xmax = max(ls_xmax)
            ymax = max(ls_ymax)

            roi = image[ymin:ymax,xmin:xmax]
            resized_roi = cv2.resize(roi, (resize_size, resize_size),interpolation=cv2.INTER_AREA)
            resized[df.index[i]] = resized_roi.reshape(-1)
    else:
        for i in range(df.shape[0]):
            #image = cv2.resize(df.loc[df.index[i]].values.reshape(137,236),(size,size),None,fx=0.5,fy=0.5,interpolation=cv2.INTER_AREA)
            image=df.loc[df.index[i]].values.reshape(137,236)
            _, thresh = cv2.threshold(image, 30, 255, cv2.THRESH_BINARY_INV + cv2.THRESH_OTSU)
            contours, _ = cv2.findContours(thresh,cv2.RETR_LIST,cv2.CHAIN_APPROX_SIMPLE)[-2:]

            idx = 0 
            ls_xmin = []
            ls_ymin = []
            ls_xmax = []
            ls_ymax = []
            for cnt in contours:
                idx += 1
                x,y,w,h = cv2.boundingRect(cnt)
                ls_xmin.append(x)
                ls_ymin.append(y)
                ls_xmax.append(x + w)
                ls_ymax.append(y + h)
            xmin = min(ls_xmin)
            ymin = min(ls_ymin)
            xmax = max(ls_xmax)
            ymax = max(ls_ymax)

            roi = image[ymin:ymax,xmin:xmax]
            resized_roi = cv2.resize(roi, (resize_size, resize_size),interpolation=cv2.INTER_AREA)
            resized[df.index[i]] = resized_roi.reshape(-1)
    resized = pd.DataFrame(resized).T
    return resized
def get_dummies(df):
    cols = []
    for col in df:
        cols.append(pd.get_dummies(df[col].astype(str)))
    return pd.concat(cols, axis=1)

# %%
inputs = Input(shape = (IMG_SIZE, IMG_SIZE, 1))

model = Conv2D(filters=32, kernel_size=(3, 3), padding='SAME', activation='relu', input_shape=(IMG_SIZE, IMG_SIZE, 1))(inputs)
model = Conv2D(filters=32, kernel_size=(3, 3), padding='SAME', activation='relu')(model)
model = Conv2D(filters=32, kernel_size=(3, 3), padding='SAME', activation='relu')(model)
model = Conv2D(filters=32, kernel_size=(3, 3), padding='SAME', activation='relu')(model)
model = BatchNormalization(momentum=0.15)(model)
model = MaxPool2D(pool_size=(2, 2))(model)
model = Conv2D(filters=32, kernel_size=(5, 5), padding='SAME', activation='relu')(model)
model = Dropout(rate=0.3)(model)

model = Conv2D(filters=64, kernel_size=(3, 3), padding='SAME', activation='relu')(model)
model = Conv2D(filters=64, kernel_size=(3, 3), padding='SAME', activation='relu')(model)
model = Conv2D(filters=64, kernel_size=(3, 3), padding='SAME', activation='relu')(model)
model = Conv2D(filters=64, kernel_size=(3, 3), padding='SAME', activation='relu')(model)
model = BatchNormalization(momentum=0.15)(model)
model = MaxPool2D(pool_size=(2, 2))(model)
model = Conv2D(filters=64, kernel_size=(5, 5), padding='SAME', activation='relu')(model)
model = BatchNormalization(momentum=0.15)(model)
model = Dropout(rate=0.3)(model)

model = Conv2D(filters=128, kernel_size=(3, 3), padding='SAME', activation='relu')(model)
model = Conv2D(filters=128, kernel_size=(3, 3), padding='SAME', activation='relu')(model)
model = Conv2D(filters=128, kernel_size=(3, 3), padding='SAME', activation='relu')(model)
model = Conv2D(filters=128, kernel_size=(3, 3), padding='SAME', activation='relu')(model)
model = BatchNormalization(momentum=0.15)(model)
model = MaxPool2D(pool_size=(2, 2))(model)
model = Conv2D(filters=128, kernel_size=(5, 5), padding='SAME', activation='relu')(model)
model = BatchNormalization(momentum=0.15)(model)
model = Dropout(rate=0.3)(model)

model = Conv2D(filters=256, kernel_size=(3, 3), padding='SAME', activation='relu')(model)
model = Conv2D(filters=256, kernel_size=(3, 3), padding='SAME', activation='relu')(model)
model = Conv2D(filters=256, kernel_size=(3, 3), padding='SAME', activation='relu')(model)
model = Conv2D(filters=256, kernel_size=(3, 3), padding='SAME', activation='relu')(model)
model = BatchNormalization(momentum=0.15)(model)
model = MaxPool2D(pool_size=(2, 2))(model)
model = Conv2D(filters=256, kernel_size=(5, 5), padding='SAME', activation='relu')(model)
model = BatchNormalization(momentum=0.15)(model)
model = Dropout(rate=0.3)(model)

model = Flatten()(model)
model = Dense(1024, activation = "relu")(model)
model = Dropout(rate=0.3)(model)
dense = Dense(512, activation = "relu")(model)

head_root = Dense(168, activation = 'softmax')(dense)
head_vowel = Dense(11, activation = 'softmax')(dense)
head_consonant = Dense(7, activation = 'softmax')(dense)

model = Model(inputs=inputs, outputs=[head_root, head_vowel, head_consonant])

# %%
model.summary()
# Out:
# Model: "model_1"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            (None, 64, 64, 1)    0
# __________________________________________________________________________________________________
# conv2d_1 (Conv2D)               (None, 64, 64, 32)   320         input_1[0][0]
# __________________________________________________________________________________________________
# conv2d_2 (Conv2D)               (None, 64, 64, 32)   9248        conv2d_1[0][0]
# __________________________________________________________________________________________________
# conv2d_3 (Conv2D)               (None, 64, 64, 32)   9248        conv2d_2[0][0]
# __________________________________________________________________________________________________
# conv2d_4 (Conv2D)               (None, 64, 64, 32)   9248        conv2d_3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_1 (BatchNor (None, 64, 64, 32)   128         conv2d_4[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_1 (MaxPooling2D)  (None, 32, 32, 32)   0           batch_normalization_1[0][0]
# __________________________________________________________________________________________________
# conv2d_5 (Conv2D)               (None, 32, 32, 32)   25632       max_pooling2d_1[0][0]
# __________________________________________________________________________________________________
# dropout_1 (Dropout)             (None, 32, 32, 32)   0           conv2d_5[0][0]
# __________________________________________________________________________________________________
# conv2d_6 (Conv2D)               (None, 32, 32, 64)   18496       dropout_1[0][0]
# __________________________________________________________________________________________________
# conv2d_7 (Conv2D)               (None, 32, 32, 64)   36928       conv2d_6[0][0]
# __________________________________________________________________________________________________
# conv2d_8 (Conv2D)               (None, 32, 32, 64)   36928       conv2d_7[0][0]
# __________________________________________________________________________________________________
# conv2d_9 (Conv2D)               (None, 32, 32, 64)   36928       conv2d_8[0][0]
# __________________________________________________________________________________________________
# batch_normalization_2 (BatchNor (None, 32, 32, 64)   256         conv2d_9[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_2 (MaxPooling2D)  (None, 16, 16, 64)   0           batch_normalization_2[0][0]
# __________________________________________________________________________________________________
# conv2d_10 (Conv2D)              (None, 16, 16, 64)   102464      max_pooling2d_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_3 (BatchNor (None, 16, 16, 64)   256         conv2d_10[0][0]
# __________________________________________________________________________________________________
# dropout_2 (Dropout)             (None, 16, 16, 64)   0           batch_normalization_3[0][0]
# __________________________________________________________________________________________________
# conv2d_11 (Conv2D)              (None, 16, 16, 128)  73856       dropout_2[0][0]
# __________________________________________________________________________________________________
# conv2d_12 (Conv2D)              (None, 16, 16, 128)  147584      conv2d_11[0][0]
# __________________________________________________________________________________________________
# conv2d_13 (Conv2D)              (None, 16, 16, 128)  147584      conv2d_12[0][0]
# __________________________________________________________________________________________________
# conv2d_14 (Conv2D)              (None, 16, 16, 128)  147584      conv2d_13[0][0]
# __________________________________________________________________________________________________
# batch_normalization_4 (BatchNor (None, 16, 16, 128)  512         conv2d_14[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_3 (MaxPooling2D)  (None, 8, 8, 128)    0           batch_normalization_4[0][0]
# __________________________________________________________________________________________________
# conv2d_15 (Conv2D)              (None, 8, 8, 128)    409728      max_pooling2d_3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_5 (BatchNor (None, 8, 8, 128)    512         conv2d_15[0][0]
# __________________________________________________________________________________________________
# dropout_3 (Dropout)             (None, 8, 8, 128)    0           batch_normalization_5[0][0]
# __________________________________________________________________________________________________
# conv2d_16 (Conv2D)              (None, 8, 8, 256)    295168      dropout_3[0][0]
# __________________________________________________________________________________________________
# conv2d_17 (Conv2D)              (None, 8, 8, 256)    590080      conv2d_16[0][0]
# __________________________________________________________________________________________________
# conv2d_18 (Conv2D)              (None, 8, 8, 256)    590080      conv2d_17[0][0]
# __________________________________________________________________________________________________
# conv2d_19 (Conv2D)              (None, 8, 8, 256)    590080      conv2d_18[0][0]
# __________________________________________________________________________________________________
# batch_normalization_6 (BatchNor (None, 8, 8, 256)    1024        conv2d_19[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_4 (MaxPooling2D)  (None, 4, 4, 256)    0           batch_normalization_6[0][0]
# __________________________________________________________________________________________________
# conv2d_20 (Conv2D)              (None, 4, 4, 256)    1638656     max_pooling2d_4[0][0]
# __________________________________________________________________________________________________
# batch_normalization_7 (BatchNor (None, 4, 4, 256)    1024        conv2d_20[0][0]
# __________________________________________________________________________________________________
# dropout_4 (Dropout)             (None, 4, 4, 256)    0           batch_normalization_7[0][0]
# __________________________________________________________________________________________________
# flatten_1 (Flatten)             (None, 4096)         0           dropout_4[0][0]
# __________________________________________________________________________________________________
# dense_1 (Dense)                 (None, 1024)         4195328     flatten_1[0][0]
# __________________________________________________________________________________________________
# dropout_5 (Dropout)             (None, 1024)         0           dense_1[0][0]
# __________________________________________________________________________________________________
# dense_2 (Dense)                 (None, 512)          524800      dropout_5[0][0]
# __________________________________________________________________________________________________
# dense_3 (Dense)                 (None, 168)          86184       dense_2[0][0]
# __________________________________________________________________________________________________
# dense_4 (Dense)                 (None, 11)           5643        dense_2[0][0]
# __________________________________________________________________________________________________
# dense_5 (Dense)                 (None, 7)            3591        dense_2[0][0]
# ==================================================================================================
# Total params: 9,735,098
# Trainable params: 9,733,242
# Non-trainable params: 1,856
# __________________________________________________________________________________________________

# %%
from keras.utils import plot_model
plot_model(model, to_file='model.png')

# %%
model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])

# %%
learning_rate_reduction_root = ReduceLROnPlateau(monitor='dense_3_accuracy', 
                                            patience=3, 
                                            verbose=1,
                                            factor=0.5, 
                                            min_lr=0.00001)
learning_rate_reduction_vowel = ReduceLROnPlateau(monitor='dense_4_accuracy', 
                                            patience=3, 
                                            verbose=1,
                                            factor=0.5, 
                                            min_lr=0.00001)
learning_rate_reduction_consonant = ReduceLROnPlateau(monitor='dense_5_accuracy', 
                                            patience=3, 
                                            verbose=1,
                                            factor=0.5, 
                                            min_lr=0.00001)

# %%
batch_size = 256
epochs = 30

# %%
class MultiOutputDataGenerator(keras.preprocessing.image.ImageDataGenerator):

    def flow(self,
             x,
             y=None,
             batch_size=32,
             shuffle=True,
             sample_weight=None,
             seed=None,
             save_to_dir=None,
             save_prefix='',
             save_format='png',
             subset=None):

        targets = None
        target_lengths = {}
        ordered_outputs = []
        for output, target in y.items():
            if targets is None:
                targets = target
            else:
                targets = np.concatenate((targets, target), axis=1)
            target_lengths[output] = target.shape[1]
            ordered_outputs.append(output)


        for flowx, flowy in super().flow(x, targets, batch_size=batch_size,
                                         shuffle=shuffle):
            target_dict = {}
            i = 0
            for output in ordered_outputs:
                target_length = target_lengths[output]
                target_dict[output] = flowy[:, i: i + target_length]
                i += target_length

            yield flowx, target_dict

# %%
HEIGHT = 137
WIDTH = 236

# %%
histories = []
for i in range(4):
    train_df = pd.merge(pd.read_parquet(f'/kaggle/input/bengaliai-cv19/train_image_data_{i}.parquet'), train_df_, on='image_id').drop(['image_id'], axis=1)
    
    # Visualize few samples of current training dataset
    fig, ax = plt.subplots(nrows=3, ncols=4, figsize=(16, 8))
    count=0
    for row in ax:
        for col in row:
            col.imshow(resize(train_df.drop(['grapheme_root', 'vowel_diacritic', 'consonant_diacritic'], axis=1).iloc[[count]], need_progress_bar=False).values.reshape(-1).reshape(IMG_SIZE, IMG_SIZE).astype(np.float64))
            count += 1
    plt.show()
    
    X_train = train_df.drop(['grapheme_root', 'vowel_diacritic', 'consonant_diacritic'], axis=1)
    X_train = resize(X_train)/255
    
    # CNN takes images in shape `(batch_size, h, w, channels)`, so reshape the images
    X_train = X_train.values.reshape(-1, IMG_SIZE, IMG_SIZE, N_CHANNELS)
    
    Y_train_root = pd.get_dummies(train_df['grapheme_root']).values
    Y_train_vowel = pd.get_dummies(train_df['vowel_diacritic']).values
    Y_train_consonant = pd.get_dummies(train_df['consonant_diacritic']).values

    print(f'Training images: {X_train.shape}')
    print(f'Training labels root: {Y_train_root.shape}')
    print(f'Training labels vowel: {Y_train_vowel.shape}')
    print(f'Training labels consonants: {Y_train_consonant.shape}')

    # Divide the data into training and validation set
    x_train, x_test, y_train_root, y_test_root, y_train_vowel, y_test_vowel, y_train_consonant, y_test_consonant = train_test_split(X_train, Y_train_root, Y_train_vowel, Y_train_consonant, test_size=0.08, random_state=666)
    del train_df
    del X_train
    del Y_train_root, Y_train_vowel, Y_train_consonant

    # Data augmentation for creating more training data
    datagen = MultiOutputDataGenerator(
        featurewise_center=False,  # set input mean to 0 over the dataset
        samplewise_center=False,  # set each sample mean to 0
        featurewise_std_normalization=False,  # divide inputs by std of the dataset
        samplewise_std_normalization=False,  # divide each input by its std
        zca_whitening=False,  # apply ZCA whitening
        rotation_range=8,  # randomly rotate images in the range (degrees, 0 to 180)
        zoom_range = 0.15, # Randomly zoom image 
        width_shift_range=0.15,  # randomly shift images horizontally (fraction of total width)
        height_shift_range=0.15,  # randomly shift images vertically (fraction of total height)
        horizontal_flip=False,  # randomly flip images
        vertical_flip=False)  # randomly flip images


    # This will just calculate parameters required to augment the given data. This won't perform any augmentations
    datagen.fit(x_train)

    # Fit the model
    history = model.fit_generator(datagen.flow(x_train, {'dense_3': y_train_root, 'dense_4': y_train_vowel, 'dense_5': y_train_consonant}, batch_size=batch_size),
                              epochs = epochs, validation_data = (x_test, [y_test_root, y_test_vowel, y_test_consonant]), 
                              steps_per_epoch=x_train.shape[0] // batch_size, 
                              callbacks=[learning_rate_reduction_root, learning_rate_reduction_vowel, learning_rate_reduction_consonant])

    histories.append(history)
    
    # Delete to reduce memory usage
    del x_train
    del x_test
    del y_train_root
    del y_test_root
    del y_train_vowel
    del y_test_vowel
    del y_train_consonant
    del y_test_consonant
    gc.collect()
# Out:
# HBox(children=(IntProgress(value=0, max=50210), HTML(value='')))
# Training images: (50210, 64, 64, 1)
# Training labels root: (50210, 168)
# Training labels vowel: (50210, 11)
# Training labels consonants: (50210, 7)
# Epoch 1/30
# 180/180 [==============================] - 43s 239ms/step - loss: 7.8995 - dense_3_loss: 4.7610 - dense_4_loss: 1.9512 - dense_5_loss: 1.1873 - dense_3_accuracy: 0.0283 - dense_4_accuracy: 0.3006 - dense_5_accuracy: 0.6244 - val_loss: 6.9359 - val_dense_3_loss: 4.5968 - val_dense_4_loss: 1.3314 - val_dense_5_loss: 1.0074 - val_dense_3_accuracy: 0.0361 - val_dense_4_accuracy: 0.5225 - val_dense_5_accuracy: 0.6520
# Epoch 2/30
# 180/180 [==============================] - 34s 191ms/step - loss: 6.9787 - dense_3_loss: 4.5581 - dense_4_loss: 1.4100 - dense_5_loss: 1.0106 - dense_3_accuracy: 0.0389 - dense_4_accuracy: 0.5076 - dense_5_accuracy: 0.6575 - val_loss: 6.3557 - val_dense_3_loss: 4.4026 - val_dense_4_loss: 1.0432 - val_dense_5_loss: 0.9096 - val_dense_3_accuracy: 0.0416 - val_dense_4_accuracy: 0.6355 - val_dense_5_accuracy: 0.6724
# Epoch 3/30
# 180/180 [==============================] - 34s 188ms/step - loss: 6.2792 - dense_3_loss: 4.3181 - dense_4_loss: 1.1099 - dense_5_loss: 0.8512 - dense_3_accuracy: 0.0527 - dense_4_accuracy: 0.6221 - dense_5_accuracy: 0.7080 - val_loss: 5.3225 - val_dense_3_loss: 3.9206 - val_dense_4_loss: 0.7275 - val_dense_5_loss: 0.6738 - val_dense_3_accuracy: 0.0794 - val_dense_4_accuracy: 0.7508 - val_dense_5_accuracy: 0.7563
# Epoch 4/30
# 180/180 [==============================] - 34s 189ms/step - loss: 5.4622 - dense_3_loss: 3.8202 - dense_4_loss: 0.9319 - dense_5_loss: 0.7101 - dense_3_accuracy: 0.0999 - dense_4_accuracy: 0.6905 - dense_5_accuracy: 0.7507 - val_loss: 4.3252 - val_dense_3_loss: 3.2477 - val_dense_4_loss: 0.5968 - val_dense_5_loss: 0.4803 - val_dense_3_accuracy: 0.1655 - val_dense_4_accuracy: 0.8041 - val_dense_5_accuracy: 0.8265
# Epoch 5/30
# 180/180 [==============================] - 34s 188ms/step - loss: 4.5832 - dense_3_loss: 3.2174 - dense_4_loss: 0.7745 - dense_5_loss: 0.5913 - dense_3_accuracy: 0.1815 - dense_4_accuracy: 0.7455 - dense_5_accuracy: 0.7988 - val_loss: 3.3159 - val_dense_3_loss: 2.5095 - val_dense_4_loss: 0.4479 - val_dense_5_loss: 0.3590 - val_dense_3_accuracy: 0.2990 - val_dense_4_accuracy: 0.8541 - val_dense_5_accuracy: 0.8808
# Epoch 6/30
# 180/180 [==============================] - 34s 189ms/step - loss: 3.9998 - dense_3_loss: 2.7369 - dense_4_loss: 0.7295 - dense_5_loss: 0.5334 - dense_3_accuracy: 0.2752 - dense_4_accuracy: 0.7610 - dense_5_accuracy: 0.8212 - val_loss: 2.9025 - val_dense_3_loss: 2.0892 - val_dense_4_loss: 0.4420 - val_dense_5_loss: 0.3714 - val_dense_3_accuracy: 0.4038 - val_dense_4_accuracy: 0.8666 - val_dense_5_accuracy: 0.8780
# Epoch 7/30
# 180/180 [==============================] - 35s 192ms/step - loss: 3.8880 - dense_3_loss: 2.5780 - dense_4_loss: 0.7597 - dense_5_loss: 0.5503 - dense_3_accuracy: 0.3187 - dense_4_accuracy: 0.7518 - dense_5_accuracy: 0.8149 - val_loss: 2.3797 - val_dense_3_loss: 1.7018 - val_dense_4_loss: 0.3823 - val_dense_5_loss: 0.2990 - val_dense_3_accuracy: 0.4897 - val_dense_4_accuracy: 0.8773 - val_dense_5_accuracy: 0.9007
# Epoch 8/30
# 180/180 [==============================] - 35s 195ms/step - loss: 3.0255 - dense_3_loss: 2.0042 - dense_4_loss: 0.5881 - dense_5_loss: 0.4332 - dense_3_accuracy: 0.4405 - dense_4_accuracy: 0.8100 - dense_5_accuracy: 0.8562 - val_loss: 1.8674 - val_dense_3_loss: 1.3461 - val_dense_4_loss: 0.2817 - val_dense_5_loss: 0.2427 - val_dense_3_accuracy: 0.6002 - val_dense_4_accuracy: 0.9131 - val_dense_5_accuracy: 0.9241
# Epoch 9/30
# 180/180 [==============================] - 35s 192ms/step - loss: 2.6020 - dense_3_loss: 1.6927 - dense_4_loss: 0.5294 - dense_5_loss: 0.3799 - dense_3_accuracy: 0.5177 - dense_4_accuracy: 0.8312 - dense_5_accuracy: 0.8736 - val_loss: 1.5939 - val_dense_3_loss: 1.1209 - val_dense_4_loss: 0.2667 - val_dense_5_loss: 0.2085 - val_dense_3_accuracy: 0.6687 - val_dense_4_accuracy: 0.9206 - val_dense_5_accuracy: 0.9313
# Epoch 10/30
# 180/180 [==============================] - 34s 189ms/step - loss: 2.3577 - dense_3_loss: 1.5195 - dense_4_loss: 0.4859 - dense_5_loss: 0.3522 - dense_3_accuracy: 0.5715 - dense_4_accuracy: 0.8442 - dense_5_accuracy: 0.8840 - val_loss: 1.4943 - val_dense_3_loss: 1.0222 - val_dense_4_loss: 0.2555 - val_dense_5_loss: 0.2171 - val_dense_3_accuracy: 0.7010 - val_dense_4_accuracy: 0.9211 - val_dense_5_accuracy: 0.9295
# Epoch 11/30
# 180/180 [==============================] - 34s 188ms/step - loss: 2.0580 - dense_3_loss: 1.2993 - dense_4_loss: 0.4410 - dense_5_loss: 0.3177 - dense_3_accuracy: 0.6283 - dense_4_accuracy: 0.8602 - dense_5_accuracy: 0.8985 - val_loss: 1.3877 - val_dense_3_loss: 0.8976 - val_dense_4_loss: 0.3152 - val_dense_5_loss: 0.1804 - val_dense_3_accuracy: 0.7503 - val_dense_4_accuracy: 0.9241 - val_dense_5_accuracy: 0.9408
# Epoch 12/30
# 180/180 [==============================] - 34s 190ms/step - loss: 2.0429 - dense_3_loss: 1.2800 - dense_4_loss: 0.4382 - dense_5_loss: 0.3247 - dense_3_accuracy: 0.6402 - dense_4_accuracy: 0.8600 - dense_5_accuracy: 0.8949 - val_loss: 1.5524 - val_dense_3_loss: 1.0392 - val_dense_4_loss: 0.2728 - val_dense_5_loss: 0.2455 - val_dense_3_accuracy: 0.7005 - val_dense_4_accuracy: 0.9218 - val_dense_5_accuracy: 0.9183
# Epoch 13/30
# 180/180 [==============================] - 34s 190ms/step - loss: 2.1520 - dense_3_loss: 1.3597 - dense_4_loss: 0.4599 - dense_5_loss: 0.3323 - dense_3_accuracy: 0.6224 - dense_4_accuracy: 0.8547 - dense_5_accuracy: 0.8910 - val_loss: 1.3584 - val_dense_3_loss: 0.9317 - val_dense_4_loss: 0.2508 - val_dense_5_loss: 0.1814 - val_dense_3_accuracy: 0.7179 - val_dense_4_accuracy: 0.9203 - val_dense_5_accuracy: 0.9435
# Epoch 14/30
# 180/180 [==============================] - 34s 187ms/step - loss: 2.1235 - dense_3_loss: 1.3247 - dense_4_loss: 0.4601 - dense_5_loss: 0.3387 - dense_3_accuracy: 0.6294 - dense_4_accuracy: 0.8558 - dense_5_accuracy: 0.8893 - val_loss: 1.4774 - val_dense_3_loss: 0.9849 - val_dense_4_loss: 0.2554 - val_dense_5_loss: 0.2421 - val_dense_3_accuracy: 0.7224 - val_dense_4_accuracy: 0.9233 - val_dense_5_accuracy: 0.9208
#
# Epoch 00014: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
#
# Epoch 00014: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# Epoch 15/30
# 180/180 [==============================] - 34s 190ms/step - loss: 1.6670 - dense_3_loss: 1.0184 - dense_4_loss: 0.3761 - dense_5_loss: 0.2726 - dense_3_accuracy: 0.7068 - dense_4_accuracy: 0.8798 - dense_5_accuracy: 0.9107 - val_loss: 1.1256 - val_dense_3_loss: 0.6960 - val_dense_4_loss: 0.2252 - val_dense_5_loss: 0.2116 - val_dense_3_accuracy: 0.8091 - val_dense_4_accuracy: 0.9487 - val_dense_5_accuracy: 0.9442
# Epoch 16/30
# 180/180 [==============================] - 34s 189ms/step - loss: 1.4257 - dense_3_loss: 0.8642 - dense_4_loss: 0.3231 - dense_5_loss: 0.2384 - dense_3_accuracy: 0.7510 - dense_4_accuracy: 0.8973 - dense_5_accuracy: 0.9212 - val_loss: 0.8744 - val_dense_3_loss: 0.5680 - val_dense_4_loss: 0.1603 - val_dense_5_loss: 0.1468 - val_dense_3_accuracy: 0.8332 - val_dense_4_accuracy: 0.9520 - val_dense_5_accuracy: 0.9507
# Epoch 17/30
# 180/180 [==============================] - 34s 189ms/step - loss: 1.3454 - dense_3_loss: 0.8162 - dense_4_loss: 0.3065 - dense_5_loss: 0.2227 - dense_3_accuracy: 0.7601 - dense_4_accuracy: 0.9015 - dense_5_accuracy: 0.9265 - val_loss: 0.8496 - val_dense_3_loss: 0.5604 - val_dense_4_loss: 0.1580 - val_dense_5_loss: 0.1316 - val_dense_3_accuracy: 0.8374 - val_dense_4_accuracy: 0.9549 - val_dense_5_accuracy: 0.9594
# Epoch 18/30
# 180/180 [==============================] - 34s 188ms/step - loss: 1.2770 - dense_3_loss: 0.7716 - dense_4_loss: 0.2919 - dense_5_loss: 0.2135 - dense_3_accuracy: 0.7742 - dense_4_accuracy: 0.9084 - dense_5_accuracy: 0.9304 - val_loss: 0.8282 - val_dense_3_loss: 0.5417 - val_dense_4_loss: 0.1655 - val_dense_5_loss: 0.1216 - val_dense_3_accuracy: 0.8449 - val_dense_4_accuracy: 0.9512 - val_dense_5_accuracy: 0.9612
# Epoch 19/30
# 180/180 [==============================] - 34s 188ms/step - loss: 1.2176 - dense_3_loss: 0.7306 - dense_4_loss: 0.2784 - dense_5_loss: 0.2086 - dense_3_accuracy: 0.7835 - dense_4_accuracy: 0.9129 - dense_5_accuracy: 0.9311 - val_loss: 0.8419 - val_dense_3_loss: 0.5426 - val_dense_4_loss: 0.1750 - val_dense_5_loss: 0.1266 - val_dense_3_accuracy: 0.8429 - val_dense_4_accuracy: 0.9529 - val_dense_5_accuracy: 0.9604
# Epoch 20/30
# 180/180 [==============================] - 34s 188ms/step - loss: 1.1523 - dense_3_loss: 0.6823 - dense_4_loss: 0.2714 - dense_5_loss: 0.1986 - dense_3_accuracy: 0.7979 - dense_4_accuracy: 0.9148 - dense_5_accuracy: 0.9353 - val_loss: 0.7918 - val_dense_3_loss: 0.5183 - val_dense_4_loss: 0.1536 - val_dense_5_loss: 0.1218 - val_dense_3_accuracy: 0.8521 - val_dense_4_accuracy: 0.9567 - val_dense_5_accuracy: 0.9604
# Epoch 21/30
# 180/180 [==============================] - 34s 190ms/step - loss: 1.1160 - dense_3_loss: 0.6613 - dense_4_loss: 0.2639 - dense_5_loss: 0.1908 - dense_3_accuracy: 0.8039 - dense_4_accuracy: 0.9177 - dense_5_accuracy: 0.9382 - val_loss: 0.7283 - val_dense_3_loss: 0.4861 - val_dense_4_loss: 0.1316 - val_dense_5_loss: 0.1121 - val_dense_3_accuracy: 0.8603 - val_dense_4_accuracy: 0.9604 - val_dense_5_accuracy: 0.9634
# Epoch 22/30
# 180/180 [==============================] - 34s 188ms/step - loss: 1.0809 - dense_3_loss: 0.6359 - dense_4_loss: 0.2566 - dense_5_loss: 0.1883 - dense_3_accuracy: 0.8111 - dense_4_accuracy: 0.9194 - dense_5_accuracy: 0.9376 - val_loss: 0.7530 - val_dense_3_loss: 0.4932 - val_dense_4_loss: 0.1448 - val_dense_5_loss: 0.1175 - val_dense_3_accuracy: 0.8566 - val_dense_4_accuracy: 0.9582 - val_dense_5_accuracy: 0.9604
# Epoch 23/30
# 180/180 [==============================] - 34s 189ms/step - loss: 1.0639 - dense_3_loss: 0.6247 - dense_4_loss: 0.2548 - dense_5_loss: 0.1843 - dense_3_accuracy: 0.8137 - dense_4_accuracy: 0.9206 - dense_5_accuracy: 0.9399 - val_loss: 0.7514 - val_dense_3_loss: 0.4976 - val_dense_4_loss: 0.1386 - val_dense_5_loss: 0.1148 - val_dense_3_accuracy: 0.8593 - val_dense_4_accuracy: 0.9619 - val_dense_5_accuracy: 0.9647
# Epoch 24/30
# 180/180 [==============================] - 34s 189ms/step - loss: 1.0146 - dense_3_loss: 0.5949 - dense_4_loss: 0.2480 - dense_5_loss: 0.1717 - dense_3_accuracy: 0.8221 - dense_4_accuracy: 0.9226 - dense_5_accuracy: 0.9443 - val_loss: 0.8140 - val_dense_3_loss: 0.4963 - val_dense_4_loss: 0.1870 - val_dense_5_loss: 0.1355 - val_dense_3_accuracy: 0.8688 - val_dense_4_accuracy: 0.9594 - val_dense_5_accuracy: 0.9637
# Epoch 25/30
# 180/180 [==============================] - 34s 191ms/step - loss: 1.0119 - dense_3_loss: 0.5951 - dense_4_loss: 0.2428 - dense_5_loss: 0.1741 - dense_3_accuracy: 0.8220 - dense_4_accuracy: 0.9245 - dense_5_accuracy: 0.9437 - val_loss: 0.7393 - val_dense_3_loss: 0.4907 - val_dense_4_loss: 0.1355 - val_dense_5_loss: 0.1135 - val_dense_3_accuracy: 0.8596 - val_dense_4_accuracy: 0.9622 - val_dense_5_accuracy: 0.9651
# Epoch 26/30
# 180/180 [==============================] - 35s 192ms/step - loss: 0.9747 - dense_3_loss: 0.5672 - dense_4_loss: 0.2379 - dense_5_loss: 0.1696 - dense_3_accuracy: 0.8294 - dense_4_accuracy: 0.9264 - dense_5_accuracy: 0.9443 - val_loss: 0.7282 - val_dense_3_loss: 0.4679 - val_dense_4_loss: 0.1404 - val_dense_5_loss: 0.1200 - val_dense_3_accuracy: 0.8671 - val_dense_4_accuracy: 0.9609 - val_dense_5_accuracy: 0.9599
# Epoch 27/30
# 180/180 [==============================] - 34s 190ms/step - loss: 0.9697 - dense_3_loss: 0.5640 - dense_4_loss: 0.2380 - dense_5_loss: 0.1677 - dense_3_accuracy: 0.8315 - dense_4_accuracy: 0.9259 - dense_5_accuracy: 0.9462 - val_loss: 0.6902 - val_dense_3_loss: 0.4520 - val_dense_4_loss: 0.1275 - val_dense_5_loss: 0.1119 - val_dense_3_accuracy: 0.8710 - val_dense_4_accuracy: 0.9664 - val_dense_5_accuracy: 0.9649
# Epoch 28/30
# 180/180 [==============================] - 35s 195ms/step - loss: 0.9520 - dense_3_loss: 0.5484 - dense_4_loss: 0.2361 - dense_5_loss: 0.1675 - dense_3_accuracy: 0.8334 - dense_4_accuracy: 0.9278 - dense_5_accuracy: 0.9473 - val_loss: 0.7033 - val_dense_3_loss: 0.4385 - val_dense_4_loss: 0.1690 - val_dense_5_loss: 0.0993 - val_dense_3_accuracy: 0.8770 - val_dense_4_accuracy: 0.9597 - val_dense_5_accuracy: 0.9701
# Epoch 29/30
# 180/180 [==============================] - 35s 197ms/step - loss: 0.9069 - dense_3_loss: 0.5217 - dense_4_loss: 0.2221 - dense_5_loss: 0.1631 - dense_3_accuracy: 0.8432 - dense_4_accuracy: 0.9303 - dense_5_accuracy: 0.9482 - val_loss: 0.7086 - val_dense_3_loss: 0.4414 - val_dense_4_loss: 0.1591 - val_dense_5_loss: 0.1094 - val_dense_3_accuracy: 0.8768 - val_dense_4_accuracy: 0.9587 - val_dense_5_accuracy: 0.9634
# Epoch 30/30
# 180/180 [==============================] - 35s 194ms/step - loss: 0.9336 - dense_3_loss: 0.5390 - dense_4_loss: 0.2285 - dense_5_loss: 0.1662 - dense_3_accuracy: 0.8384 - dense_4_accuracy: 0.9279 - dense_5_accuracy: 0.9463 - val_loss: 0.6549 - val_dense_3_loss: 0.4401 - val_dense_4_loss: 0.1119 - val_dense_5_loss: 0.1035 - val_dense_3_accuracy: 0.8703 - val_dense_4_accuracy: 0.9689 - val_dense_5_accuracy: 0.9701
# HBox(children=(IntProgress(value=0, max=50210), HTML(value='')))
# Training images: (50210, 64, 64, 1)
# Training labels root: (50210, 168)
# Training labels vowel: (50210, 11)
# Training labels consonants: (50210, 7)
# Epoch 1/30
# 180/180 [==============================] - 36s 201ms/step - loss: 1.1898 - dense_3_loss: 0.7206 - dense_4_loss: 0.2664 - dense_5_loss: 0.2028 - dense_3_accuracy: 0.7973 - dense_4_accuracy: 0.9190 - dense_5_accuracy: 0.9344 - val_loss: 0.7064 - val_dense_3_loss: 0.4385 - val_dense_4_loss: 0.1501 - val_dense_5_loss: 0.1159 - val_dense_3_accuracy: 0.8743 - val_dense_4_accuracy: 0.9577 - val_dense_5_accuracy: 0.9639
# Epoch 2/30
# 180/180 [==============================] - 35s 197ms/step - loss: 1.0972 - dense_3_loss: 0.6583 - dense_4_loss: 0.2528 - dense_5_loss: 0.1861 - dense_3_accuracy: 0.8122 - dense_4_accuracy: 0.9228 - dense_5_accuracy: 0.9401 - val_loss: 0.6245 - val_dense_3_loss: 0.4081 - val_dense_4_loss: 0.1147 - val_dense_5_loss: 0.1004 - val_dense_3_accuracy: 0.8842 - val_dense_4_accuracy: 0.9691 - val_dense_5_accuracy: 0.9679
# Epoch 3/30
# 180/180 [==============================] - 35s 192ms/step - loss: 1.0488 - dense_3_loss: 0.6248 - dense_4_loss: 0.2444 - dense_5_loss: 0.1795 - dense_3_accuracy: 0.8218 - dense_4_accuracy: 0.9252 - dense_5_accuracy: 0.9427 - val_loss: 0.6554 - val_dense_3_loss: 0.4046 - val_dense_4_loss: 0.1387 - val_dense_5_loss: 0.1111 - val_dense_3_accuracy: 0.8845 - val_dense_4_accuracy: 0.9659 - val_dense_5_accuracy: 0.9624
# Epoch 4/30
# 180/180 [==============================] - 35s 197ms/step - loss: 0.9982 - dense_3_loss: 0.5959 - dense_4_loss: 0.2352 - dense_5_loss: 0.1671 - dense_3_accuracy: 0.8271 - dense_4_accuracy: 0.9280 - dense_5_accuracy: 0.9475 - val_loss: 1.0389 - val_dense_3_loss: 0.6115 - val_dense_4_loss: 0.2910 - val_dense_5_loss: 0.1533 - val_dense_3_accuracy: 0.8860 - val_dense_4_accuracy: 0.9572 - val_dense_5_accuracy: 0.9642
# Epoch 5/30
# 180/180 [==============================] - 35s 196ms/step - loss: 0.9538 - dense_3_loss: 0.5586 - dense_4_loss: 0.2291 - dense_5_loss: 0.1660 - dense_3_accuracy: 0.8382 - dense_4_accuracy: 0.9298 - dense_5_accuracy: 0.9480 - val_loss: 0.6959 - val_dense_3_loss: 0.4106 - val_dense_4_loss: 0.1804 - val_dense_5_loss: 0.1048 - val_dense_3_accuracy: 0.8880 - val_dense_4_accuracy: 0.9577 - val_dense_5_accuracy: 0.9684
# Epoch 6/30
# 180/180 [==============================] - 36s 199ms/step - loss: 0.9263 - dense_3_loss: 0.5375 - dense_4_loss: 0.2290 - dense_5_loss: 0.1598 - dense_3_accuracy: 0.8419 - dense_4_accuracy: 0.9294 - dense_5_accuracy: 0.9499 - val_loss: 0.6225 - val_dense_3_loss: 0.3675 - val_dense_4_loss: 0.1434 - val_dense_5_loss: 0.1109 - val_dense_3_accuracy: 0.8982 - val_dense_4_accuracy: 0.9597 - val_dense_5_accuracy: 0.9666
# Epoch 7/30
# 180/180 [==============================] - 45s 252ms/step - loss: 0.8945 - dense_3_loss: 0.5202 - dense_4_loss: 0.2159 - dense_5_loss: 0.1584 - dense_3_accuracy: 0.8470 - dense_4_accuracy: 0.9330 - dense_5_accuracy: 0.9489 - val_loss: 0.6504 - val_dense_3_loss: 0.3745 - val_dense_4_loss: 0.1756 - val_dense_5_loss: 0.0985 - val_dense_3_accuracy: 0.8920 - val_dense_4_accuracy: 0.9649 - val_dense_5_accuracy: 0.9684
# Epoch 8/30
# 180/180 [==============================] - 46s 256ms/step - loss: 0.8714 - dense_3_loss: 0.4996 - dense_4_loss: 0.2144 - dense_5_loss: 0.1575 - dense_3_accuracy: 0.8526 - dense_4_accuracy: 0.9348 - dense_5_accuracy: 0.9490 - val_loss: 1.3039 - val_dense_3_loss: 0.7118 - val_dense_4_loss: 0.4291 - val_dense_5_loss: 0.1630 - val_dense_3_accuracy: 0.8982 - val_dense_4_accuracy: 0.9584 - val_dense_5_accuracy: 0.9706
# Epoch 9/30
# 180/180 [==============================] - 47s 260ms/step - loss: 0.8552 - dense_3_loss: 0.4901 - dense_4_loss: 0.2089 - dense_5_loss: 0.1562 - dense_3_accuracy: 0.8567 - dense_4_accuracy: 0.9362 - dense_5_accuracy: 0.9494 - val_loss: 0.5536 - val_dense_3_loss: 0.3450 - val_dense_4_loss: 0.1163 - val_dense_5_loss: 0.0929 - val_dense_3_accuracy: 0.9014 - val_dense_4_accuracy: 0.9661 - val_dense_5_accuracy: 0.9714
#
# Epoch 00009: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
# Epoch 10/30
# 180/180 [==============================] - 48s 269ms/step - loss: 0.7775 - dense_3_loss: 0.4393 - dense_4_loss: 0.1988 - dense_5_loss: 0.1394 - dense_3_accuracy: 0.8674 - dense_4_accuracy: 0.9397 - dense_5_accuracy: 0.9553 - val_loss: 0.6612 - val_dense_3_loss: 0.3817 - val_dense_4_loss: 0.1813 - val_dense_5_loss: 0.0972 - val_dense_3_accuracy: 0.9022 - val_dense_4_accuracy: 0.9654 - val_dense_5_accuracy: 0.9701
# Epoch 11/30
# 180/180 [==============================] - 47s 260ms/step - loss: 0.7620 - dense_3_loss: 0.4293 - dense_4_loss: 0.1924 - dense_5_loss: 0.1402 - dense_3_accuracy: 0.8727 - dense_4_accuracy: 0.9418 - dense_5_accuracy: 0.9550 - val_loss: 0.5186 - val_dense_3_loss: 0.3201 - val_dense_4_loss: 0.1111 - val_dense_5_loss: 0.0883 - val_dense_3_accuracy: 0.9047 - val_dense_4_accuracy: 0.9716 - val_dense_5_accuracy: 0.9729
# Epoch 12/30
# 180/180 [==============================] - 37s 207ms/step - loss: 0.7270 - dense_3_loss: 0.4093 - dense_4_loss: 0.1885 - dense_5_loss: 0.1293 - dense_3_accuracy: 0.8774 - dense_4_accuracy: 0.9427 - dense_5_accuracy: 0.9577 - val_loss: 0.4998 - val_dense_3_loss: 0.3159 - val_dense_4_loss: 0.1008 - val_dense_5_loss: 0.0825 - val_dense_3_accuracy: 0.9084 - val_dense_4_accuracy: 0.9746 - val_dense_5_accuracy: 0.9739
# Epoch 13/30
# 180/180 [==============================] - 41s 226ms/step - loss: 0.7198 - dense_3_loss: 0.4046 - dense_4_loss: 0.1833 - dense_5_loss: 0.1319 - dense_3_accuracy: 0.8771 - dense_4_accuracy: 0.9446 - dense_5_accuracy: 0.9577 - val_loss: 0.9028 - val_dense_3_loss: 0.5231 - val_dense_4_loss: 0.2593 - val_dense_5_loss: 0.1283 - val_dense_3_accuracy: 0.9044 - val_dense_4_accuracy: 0.9676 - val_dense_5_accuracy: 0.9706
# Epoch 14/30
# 180/180 [==============================] - 59s 330ms/step - loss: 0.7097 - dense_3_loss: 0.4010 - dense_4_loss: 0.1819 - dense_5_loss: 0.1268 - dense_3_accuracy: 0.8786 - dense_4_accuracy: 0.9444 - dense_5_accuracy: 0.9583 - val_loss: 0.5377 - val_dense_3_loss: 0.3301 - val_dense_4_loss: 0.1149 - val_dense_5_loss: 0.0936 - val_dense_3_accuracy: 0.9064 - val_dense_4_accuracy: 0.9686 - val_dense_5_accuracy: 0.9706
# Epoch 15/30
# 180/180 [==============================] - 61s 339ms/step - loss: 0.6977 - dense_3_loss: 0.3905 - dense_4_loss: 0.1765 - dense_5_loss: 0.1307 - dense_3_accuracy: 0.8815 - dense_4_accuracy: 0.9450 - dense_5_accuracy: 0.9584 - val_loss: 0.5345 - val_dense_3_loss: 0.3346 - val_dense_4_loss: 0.1079 - val_dense_5_loss: 0.0922 - val_dense_3_accuracy: 0.9054 - val_dense_4_accuracy: 0.9686 - val_dense_5_accuracy: 0.9734
# Epoch 16/30
# 180/180 [==============================] - 55s 308ms/step - loss: 0.7024 - dense_3_loss: 0.3924 - dense_4_loss: 0.1805 - dense_5_loss: 0.1295 - dense_3_accuracy: 0.8816 - dense_4_accuracy: 0.9447 - dense_5_accuracy: 0.9584 - val_loss: 0.5223 - val_dense_3_loss: 0.3267 - val_dense_4_loss: 0.1076 - val_dense_5_loss: 0.0889 - val_dense_3_accuracy: 0.9089 - val_dense_4_accuracy: 0.9734 - val_dense_5_accuracy: 0.9739
# Epoch 17/30
# 180/180 [==============================] - 64s 356ms/step - loss: 0.6697 - dense_3_loss: 0.3740 - dense_4_loss: 0.1753 - dense_5_loss: 0.1203 - dense_3_accuracy: 0.8843 - dense_4_accuracy: 0.9461 - dense_5_accuracy: 0.9606 - val_loss: 0.5026 - val_dense_3_loss: 0.3117 - val_dense_4_loss: 0.1097 - val_dense_5_loss: 0.0818 - val_dense_3_accuracy: 0.9126 - val_dense_4_accuracy: 0.9689 - val_dense_5_accuracy: 0.9771
# Epoch 18/30
# 180/180 [==============================] - 56s 312ms/step - loss: 0.6019 - dense_3_loss: 0.3343 - dense_4_loss: 0.1555 - dense_5_loss: 0.1121 - dense_3_accuracy: 0.8976 - dense_4_accuracy: 0.9517 - dense_5_accuracy: 0.9640 - val_loss: 0.5206 - val_dense_3_loss: 0.3080 - val_dense_4_loss: 0.1285 - val_dense_5_loss: 0.0830 - val_dense_3_accuracy: 0.9159 - val_dense_4_accuracy: 0.9679 - val_dense_5_accuracy: 0.9766
# Epoch 25/30
# 180/180 [==============================] - 35s 196ms/step - loss: 0.5922 - dense_3_loss: 0.3226 - dense_4_loss: 0.1610 - dense_5_loss: 0.1086 - dense_3_accuracy: 0.9007 - dense_4_accuracy: 0.9516 - dense_5_accuracy: 0.9645 - val_loss: 0.5752 - val_dense_3_loss: 0.3555 - val_dense_4_loss: 0.1310 - val_dense_5_loss: 0.0876 - val_dense_3_accuracy: 0.9144 - val_dense_4_accuracy: 0.9671 - val_dense_5_accuracy: 0.9751
# Epoch 26/30
# 180/180 [==============================] - 40s 220ms/step - loss: 0.8168 - dense_3_loss: 0.4795 - dense_4_loss: 0.1928 - dense_5_loss: 0.1444 - dense_3_accuracy: 0.8617 - dense_4_accuracy: 0.9424 - dense_5_accuracy: 0.9541 - val_loss: 0.4876 - val_dense_3_loss: 0.2965 - val_dense_4_loss: 0.0998 - val_dense_5_loss: 0.0911 - val_dense_3_accuracy: 0.9166 - val_dense_4_accuracy: 0.9719 - val_dense_5_accuracy: 0.9699
# Epoch 3/30
# 180/180 [==============================] - 35s 195ms/step - loss: 0.7757 - dense_3_loss: 0.4529 - dense_4_loss: 0.1850 - dense_5_loss: 0.1378 - dense_3_accuracy: 0.8683 - dense_4_accuracy: 0.9440 - dense_5_accuracy: 0.9554 - val_loss: 0.6124 - val_dense_3_loss: 0.3766 - val_dense_4_loss: 0.1287 - val_dense_5_loss: 0.1179 - val_dense_3_accuracy: 0.9171 - val_dense_4_accuracy: 0.9694 - val_dense_5_accuracy: 0.9711
# Epoch 4/30
# 180/180 [==============================] - 35s 195ms/step - loss: 0.7484 - dense_3_loss: 0.4368 - dense_4_loss: 0.1795 - dense_5_loss: 0.1320 - dense_3_accuracy: 0.8743 - dense_4_accuracy: 0.9463 - dense_5_accuracy: 0.9589 - val_loss: 0.5374 - val_dense_3_loss: 0.3185 - val_dense_4_loss: 0.1145 - val_dense_5_loss: 0.1083 - val_dense_3_accuracy: 0.9186 - val_dense_4_accuracy: 0.9711 - val_dense_5_accuracy: 0.9704
# Epoch 5/30
# 180/180 [==============================] - 57s 315ms/step - loss: 0.5920 - dense_3_loss: 0.3270 - dense_4_loss: 0.1544 - dense_5_loss: 0.1107 - dense_3_accuracy: 0.9010 - dense_4_accuracy: 0.9527 - dense_5_accuracy: 0.9638 - val_loss: 0.4748 - val_dense_3_loss: 0.2848 - val_dense_4_loss: 0.0970 - val_dense_5_loss: 0.0938 - val_dense_3_accuracy: 0.9276 - val_dense_4_accuracy: 0.9721 - val_dense_5_accuracy: 0.9726
# Epoch 15/30
# 180/180 [==============================] - 56s 312ms/step - loss: 0.5786 - dense_3_loss: 0.3214 - dense_4_loss: 0.1510 - dense_5_loss: 0.1062 - dense_3_accuracy: 0.9030 - dense_4_accuracy: 0.9536 - dense_5_accuracy: 0.9661 - val_loss: 0.4654 - val_dense_3_loss: 0.2818 - val_dense_4_loss: 0.0964 - val_dense_5_loss: 0.0886 - val_dense_3_accuracy: 0.9256 - val_dense_4_accuracy: 0.9736 - val_dense_5_accuracy: 0.9739
# Epoch 16/30
# 180/180 [==============================] - 57s 317ms/step - loss: 0.5776 - dense_3_loss: 0.3167 - dense_4_loss: 0.1526 - dense_5_loss: 0.1083 - dense_3_accuracy: 0.9037 - dense_4_accuracy: 0.9525 - dense_5_accuracy: 0.9651 - val_loss: 0.4691 - val_dense_3_loss: 0.2877 - val_dense_4_loss: 0.0919 - val_dense_5_loss: 0.0948 - val_dense_3_accuracy: 0.9246 - val_dense_4_accuracy: 0.9734 - val_dense_5_accuracy: 0.9741
# Epoch 17/30
# 180/180 [==============================] - 55s 304ms/step - loss: 0.5101 - dense_3_loss: 0.2810 - dense_4_loss: 0.1330 - dense_5_loss: 0.0961 - dense_3_accuracy: 0.9122 - dense_4_accuracy: 0.9594 - dense_5_accuracy: 0.9685 - val_loss: 0.4464 - val_dense_3_loss: 0.2613 - val_dense_4_loss: 0.0975 - val_dense_5_loss: 0.0892 - val_dense_3_accuracy: 0.9266 - val_dense_4_accuracy: 0.9749 - val_dense_5_accuracy: 0.9754
# Epoch 24/30
# 180/180 [==============================] - 48s 267ms/step - loss: 0.5226 - dense_3_loss: 0.2819 - dense_4_loss: 0.1388 - dense_5_loss: 0.1019 - dense_3_accuracy: 0.9136 - dense_4_accuracy: 0.9571 - dense_5_accuracy: 0.9672 - val_loss: 0.5262 - val_dense_3_loss: 0.2927 - val_dense_4_loss: 0.1158 - val_dense_5_loss: 0.1258 - val_dense_3_accuracy: 0.9278 - val_dense_4_accuracy: 0.9716 - val_dense_5_accuracy: 0.9724
# Epoch 25/30
# 180/180 [==============================] - 52s 289ms/step - loss: 0.4952 - dense_3_loss: 0.2680 - dense_4_loss: 0.1333 - dense_5_loss: 0.0939 - dense_3_accuracy: 0.9170 - dense_4_accuracy: 0.9591 - dense_5_accuracy: 0.9692 - val_loss: 0.4932 - val_dense_3_loss: 0.2689 - val_dense_4_loss: 0.1041 - val_dense_5_loss: 0.1301 - val_dense_3_accuracy: 0.9271 - val_dense_4_accuracy: 0.9739 - val_dense_5_accuracy: 0.9736
# Epoch 26/30
# 109/180 [=================>............] - ETA: 21s - loss: 0.4858 - dense_3_loss: 0.2556 - dense_4_loss: 0.1367 - dense_5_loss: 0.0936 - dense_3_accuracy: 0.9207 - dense_4_accuracy: 0.9576 - dense_5_accuracy: 0.9697
# HBox(children=(IntProgress(value=0, max=50210), HTML(value='')))
# 180/180 [==============================] - 34s 191ms/step - loss: 0.5797 - dense_3_loss: 0.3285 - dense_4_loss: 0.1473 - dense_5_loss: 0.1040 - dense_3_accuracy: 0.9033 - dense_4_accuracy: 0.9551 - dense_5_accuracy: 0.9673 - val_loss: 0.4166 - val_dense_3_loss: 0.2550 - val_dense_4_loss: 0.0916 - val_dense_5_loss: 0.0769 - val_dense_3_accuracy: 0.9273 - val_dense_4_accuracy: 0.9764 - val_dense_5_accuracy: 0.9828
# Epoch 10/30
# 180/180 [==============================] - 34s 191ms/step - loss: 0.5691 - dense_3_loss: 0.3189 - dense_4_loss: 0.1483 - dense_5_loss: 0.1020 - dense_3_accuracy: 0.9050 - dense_4_accuracy: 0.9560 - dense_5_accuracy: 0.9681 - val_loss: 0.3951 - val_dense_3_loss: 0.2454 - val_dense_4_loss: 0.0861 - val_dense_5_loss: 0.0656 - val_dense_3_accuracy: 0.9283 - val_dense_4_accuracy: 0.9778 - val_dense_5_accuracy: 0.9833
# Epoch 11/30
# 180/180 [==============================] - 34s 188ms/step - loss: 0.5645 - dense_3_loss: 0.3168 - dense_4_loss: 0.1434 - dense_5_loss: 0.1043 - dense_3_accuracy: 0.9041 - dense_4_accuracy: 0.9561 - dense_5_accuracy: 0.9665 - val_loss: 0.3765 - val_dense_3_loss: 0.2384 - val_dense_4_loss: 0.0837 - val_dense_5_loss: 0.0564 - val_dense_3_accuracy: 0.9338 - val_dense_4_accuracy: 0.9801 - val_dense_5_accuracy: 0.9841
# Epoch 12/30
# 180/180 [==============================] - 34s 191ms/step - loss: 0.5503 - dense_3_loss: 0.3098 - dense_4_loss: 0.1390 - dense_5_loss: 0.1015 - dense_3_accuracy: 0.9073 - dense_4_accuracy: 0.9582 - dense_5_accuracy: 0.9682 - val_loss: 0.3801 - val_dense_3_loss: 0.2342 - val_dense_4_loss: 0.0838 - val_dense_5_loss: 0.0612 - val_dense_3_accuracy: 0.9340 - val_dense_4_accuracy: 0.9793 - val_dense_5_accuracy: 0.9833
# Epoch 13/30
# 180/180 [==============================] - 35s 193ms/step - loss: 0.5431 - dense_3_loss: 0.3035 - dense_4_loss: 0.1430 - dense_5_loss: 0.0966 - dense_3_accuracy: 0.9090 - dense_4_accuracy: 0.9574 - dense_5_accuracy: 0.9705 - val_loss: 0.4235 - val_dense_3_loss: 0.2591 - val_dense_4_loss: 0.0952 - val_dense_5_loss: 0.0752 - val_dense_3_accuracy: 0.9320 - val_dense_4_accuracy: 0.9781 - val_dense_5_accuracy: 0.9821
# Epoch 14/30
# 180/180 [==============================] - 35s 193ms/step - loss: 0.5303 - dense_3_loss: 0.2932 - dense_4_loss: 0.1374 - dense_5_loss: 0.0997 - dense_3_accuracy: 0.9116 - dense_4_accuracy: 0.9582 - dense_5_accuracy: 0.9689 - val_loss: 0.3834 - val_dense_3_loss: 0.2331 - val_dense_4_loss: 0.0892 - val_dense_5_loss: 0.0606 - val_dense_3_accuracy: 0.9303 - val_dense_4_accuracy: 0.9764 - val_dense_5_accuracy: 0.9823
# Epoch 15/30
# 180/180 [==============================] - 35s 192ms/step - loss: 0.5307 - dense_3_loss: 0.2965 - dense_4_loss: 0.1341 - dense_5_loss: 0.1001 - dense_3_accuracy: 0.9102 - dense_4_accuracy: 0.9595 - dense_5_accuracy: 0.9679 - val_loss: 0.3789 - val_dense_3_loss: 0.2372 - val_dense_4_loss: 0.0831 - val_dense_5_loss: 0.0585 - val_dense_3_accuracy: 0.9325 - val_dense_4_accuracy: 0.9798 - val_dense_5_accuracy: 0.9833
# Epoch 16/30
# 180/180 [==============================] - 34s 191ms/step - loss: 0.5110 - dense_3_loss: 0.2826 - dense_4_loss: 0.1344 - dense_5_loss: 0.0940 - dense_3_accuracy: 0.9133 - dense_4_accuracy: 0.9593 - dense_5_accuracy: 0.9702 - val_loss: 0.5960 - val_dense_3_loss: 0.3579 - val_dense_4_loss: 0.1422 - val_dense_5_loss: 0.1179 - val_dense_3_accuracy: 0.9328 - val_dense_4_accuracy: 0.9781 - val_dense_5_accuracy: 0.9818
#
# Epoch 00016: ReduceLROnPlateau reducing learning rate to 3.125000148429535e-05.
# Epoch 17/30
#  77/180 [===========>..................] - ETA: 18s - loss: 0.4930 - dense_3_loss: 0.2756 - dense_4_loss: 0.1278 - dense_5_loss: 0.0895 - dense_3_accuracy: 0.9168 - dense_4_accuracy: 0.9617 - dense_5_accuracy: 0.9708

# %%
# %matplotlib inline
def plot_loss(his, epoch, title):
    plt.style.use('ggplot')
    plt.figure()
    plt.plot(np.arange(0, epoch), his.history['loss'], label='train_loss')
    plt.plot(np.arange(0, epoch), his.history['dense_3_loss'], label='train_root_loss')
    plt.plot(np.arange(0, epoch), his.history['dense_4_loss'], label='train_vowel_loss')
    plt.plot(np.arange(0, epoch), his.history['dense_5_loss'], label='train_consonant_loss')
    
    plt.plot(np.arange(0, epoch), his.history['val_dense_3_loss'], label='val_train_root_loss')
    plt.plot(np.arange(0, epoch), his.history['val_dense_4_loss'], label='val_train_vowel_loss')
    plt.plot(np.arange(0, epoch), his.history['val_dense_5_loss'], label='val_train_consonant_loss')
    
    plt.title(title)
    plt.xlabel('Epoch #')
    plt.ylabel('Loss')
    plt.legend(loc='upper right')
    plt.show()

def plot_acc(his, epoch, title):
    plt.style.use('ggplot')
    plt.figure()
    plt.plot(np.arange(0, epoch), his.history['dense_3_accuracy'], label='train_root_acc')
    plt.plot(np.arange(0, epoch), his.history['dense_4_accuracy'], label='train_vowel_accuracy')
    plt.plot(np.arange(0, epoch), his.history['dense_5_accuracy'], label='train_consonant_accuracy')
    
    plt.plot(np.arange(0, epoch), his.history['val_dense_3_accuracy'], label='val_root_acc')
    plt.plot(np.arange(0, epoch), his.history['val_dense_4_accuracy'], label='val_vowel_accuracy')
    plt.plot(np.arange(0, epoch), his.history['val_dense_5_accuracy'], label='val_consonant_accuracy')
    plt.title(title)
    plt.xlabel('Epoch #')
    plt.ylabel('Accuracy')
    plt.legend(loc='upper right')
    plt.show()

# %%
for dataset in range(4):
    plot_loss(histories[dataset], epochs, f'Training Dataset: {dataset}')
    plot_acc(histories[dataset], epochs, f'Training Dataset: {dataset}')

# %%
del histories
gc.collect()
# Out:
# 27343

# %%
preds_dict = {
    'grapheme_root': [],
    'vowel_diacritic': [],
    'consonant_diacritic': []
}

# %%
components = ['consonant_diacritic', 'grapheme_root', 'vowel_diacritic']
target=[] # model predictions placeholder
row_id=[] # row_id place holder
for i in range(4):
    df_test_img = pd.read_parquet('/kaggle/input/bengaliai-cv19/test_image_data_{}.parquet'.format(i)) 
    df_test_img.set_index('image_id', inplace=True)

    X_test = resize(df_test_img, need_progress_bar=False)/255
    X_test = X_test.values.reshape(-1, IMG_SIZE, IMG_SIZE, N_CHANNELS)
    
    preds = model.predict(X_test)

    for i, p in enumerate(preds_dict):
        preds_dict[p] = np.argmax(preds[i], axis=1)

    for k,id in enumerate(df_test_img.index.values):  
        for i,comp in enumerate(components):
            id_sample=id+'_'+comp
            row_id.append(id_sample)
            target.append(preds_dict[comp][k])
    del df_test_img
    del X_test
    gc.collect()

df_sample = pd.DataFrame(
    {
        'row_id': row_id,
        'target':target
    },
    columns = ['row_id','target'] 
)
df_sample.to_csv('submission.csv',index=False)
df_sample.head()
# Out:
#                        row_id  target
# 0  Test_0_consonant_diacritic       0
# 1        Test_0_grapheme_root       3
# 2      Test_0_vowel_diacritic       0
# 3  Test_1_consonant_diacritic       0
# 4        Test_1_grapheme_root      93
